# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
path = "ceidg_data_surv.csv"
df = pd.read_csv(path)

# %%
df.columns
# Out:
# Index(['Status', 'YearOfStartingOfTheBusiness', 'DateOfStartingOfTheBusiness',
#        'DateOfTermination', 'Terminated', 'DurationOfExistenceInMonths',
#        'MainAddressVoivodeship', 'MainAddressCounty', 'MainAddressTERC',
#        'CorrespondenceAddressVoivodeship', 'CorrespondenceAddressCounty',
#        'CorrespondenceAddressTERC', 'MainAndCorrespondenceAreTheSame',
#        'NoOfAdditionalPlaceOfTheBusiness', 'IsPhoneNo', 'IsEmail', 'IsWWW',
#        'CommunityProperty', 'HasLicences', 'NoOfLicences', 'Sex',
#        'HasPolishCitizenship', 'ShareholderInOtherCompanies', 'PKDMainSection',
#        'PKDMainDivision', 'PKDMainGroup', 'PKDMainClass',
#        'NoOfUniquePKDSections', 'NoOfUniquePKDDivsions', 'NoOfUniquePKDGroups',
#        'NoOfUniquePKDClasses'],
#       dtype='object')

# %%
print(df.loc[1,:])
# Out:
# Status                               Wykreślony
# YearOfStartingOfTheBusiness                2011
# DateOfStartingOfTheBusiness          2011-01-01
# DateOfTermination                    2015-08-06
# Terminated                                    1
# DurationOfExistenceInMonths                  55
# MainAddressVoivodeship              MAZOWIECKIE
# MainAddressCounty                      WARSZAWA
# MainAddressTERC                     1.46508e+06
# CorrespondenceAddressVoivodeship    MAZOWIECKIE
# CorrespondenceAddressCounty            WARSZAWA
# CorrespondenceAddressTERC           1.46508e+06
# MainAndCorrespondenceAreTheSame            True
# NoOfAdditionalPlaceOfTheBusiness              0
# IsPhoneNo                                 False
# IsEmail                                   False
# IsWWW                                     False
# CommunityProperty                             -
# HasLicences                               False
# NoOfLicences                                  0
# ...

# %%
correct_voivodeships = ['dolnośląskie', 'mazowieckie','kujawsko-pomorskie','małopolskie',
                       'zachodniopomorskie', 'łódzkie', 'lubelskie', 'pomorskie',
                        'podkarpackie', 'śląskie', 'warmińsko-mazurskie', 'świętokrzyskie',
                       'podlaskie', 'wielkopolskie', 'lubuskie', 'opolskie']
df['MainAddressVoivodeship'] = df['MainAddressVoivodeship'].str.lower()
df['MainAddressVoivodeship'].unique()
# Out:
# array(['dolnośląskie', 'mazowieckie', 'kujawsko-pomorskie', nan,
#        'małopolskie', 'zachodniopomorskie', 'łódzkie', 'lubelskie',
#        'pomorskie', 'podkarpackie', 'śląskie', 'warmińsko-mazurskie',
#        'świętokrzyskie', 'podlaskie', 'wielkopolskie', 'lubuskie',
#        'opolskie', 'kuj pomorskie', 'małopolska', 'malopolskie', 'czersk',
#        'tolkmicko', 'kwidzyn', 'pomorski', 'deszczno', 'gorzów wlkp.',
#        'hajnwka', 'dolnosląskie', 'zachondiopomorskie',
#        'zachodniopomorski', 'zagórz', 'kraków', 'brzozów', 'sanok',
#        'małoplskie', 'polska', 'warm-maz', 'warmi�sko-mazurskie',
#        'warmińsko-mazurskiego', 'wielkopolski', 'wielskopolskie',
#        'wielkopolska', 'zachodno-pomorskie', 'chodzież', 'szamocin',
#        'łodzkie', 'skoki', 'opalenica', 'miłosław', 'swiętoktrzyskie',
#        'sochaczew', 'mazopwieckie', 'człuchów', 'stargard szczeciński',
#        'mielno', 'szczecin', 'kobylanka', 'zaleszany', 'świetokrzyskie',
# ...

# %%
correct_records = df['MainAddressVoivodeship'].isin(correct_voivodeships)

# %%
df[correct_records].hist(column='DurationOfExistenceInMonths')
df[~correct_records].hist(column='DurationOfExistenceInMonths')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001E803991448>]],
#       dtype=object)

# %%
df[correct_records].corr()
# Out:
#                                   YearOfStartingOfTheBusiness  Terminated  \
# YearOfStartingOfTheBusiness                               NaN         NaN
# Terminated                                                NaN    1.000000
# DurationOfExistenceInMonths                               NaN   -0.845546
# MainAddressTERC                                           NaN    0.002359
# CorrespondenceAddressTERC                                 NaN   -0.000691
# MainAndCorrespondenceAreTheSame                           NaN   -0.017071
# NoOfAdditionalPlaceOfTheBusiness                          NaN   -0.116024
# IsPhoneNo                                                 NaN   -0.135248
# IsEmail                                                   NaN   -0.028107
# IsWWW                                                     NaN   -0.067070
# HasLicences                                               NaN   -0.199515
# NoOfLicences                                              NaN   -0.150748
# ...

# %%
df[~correct_records].corr()
# Out:
#                                   YearOfStartingOfTheBusiness  Terminated  \
# YearOfStartingOfTheBusiness                               NaN         NaN
# Terminated                                                NaN    1.000000
# DurationOfExistenceInMonths                               NaN   -0.934298
# MainAddressTERC                                           NaN   -0.258199
# CorrespondenceAddressTERC                                 NaN   -0.016261
# MainAndCorrespondenceAreTheSame                           NaN    0.916925
# NoOfAdditionalPlaceOfTheBusiness                          NaN    0.163830
# IsPhoneNo                                                 NaN   -0.241192
# IsEmail                                                   NaN   -0.103049
# IsWWW                                                     NaN   -0.161606
# HasLicences                                               NaN   -0.211817
# NoOfLicences                                              NaN   -0.200972
# ...

# %%
df[~correct_records]
# Out:
#             Status  YearOfStartingOfTheBusiness DateOfStartingOfTheBusiness  \
# 18      Wykreślony                         2011                  2011-05-15
# 44      Wykreślony                         2011                  2011-04-02
# 117        Aktywny                         2011                  2011-08-01
# 128     Wykreślony                         2011                  2011-05-10
# 217        Aktywny                         2011                  2011-01-17
# ...            ...                          ...                         ...
# 286604  Wykreślony                         2011                  2011-09-02
# 286670  Wykreślony                         2011                  2011-05-01
# 286858  Wykreślony                         2011                  2011-06-01
# 286939     Aktywny                         2011                  2011-08-01
# 286990  Wykreślony                         2011                  2011-11-02
#
# ...

# %%
df[~correct_records].hist(column='Terminated', by='HasPolishCitizenship')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000001E8023312C8>,
# ...
#       dtype=object)

# %%
df[~correct_records].hist(column='DurationOfExistenceInMonths', by='HasPolishCitizenship')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000001E8023ECE08>,
# ...
#       dtype=object)

# %%
df[~correct_records].hist(column='DurationOfExistenceInMonths', by='IsPhoneNo')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000001E8023ECCC8>,
# ...
#       dtype=object)

# %%
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001E8060C2708>]],
#       dtype=object)

# %%
fig = df[correct_records].hist(column='DurationOfExistenceInMonths', by='MainAddressVoivodeship', figsize=(200,200))
[x.title.set_size(80) for x in fig.ravel()]
[x.]
# Out:
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %%
#df[correct_records].hist(column='Terminated', by='MainAndCorrespondenceAreTheSame')
df[~correct_records].hist(column='Terminated', by='MainAndCorrespondenceAreTheSame')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000001E802A3F608>,
# ...
#       dtype=object)
